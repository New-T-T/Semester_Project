# %%
# !pip install brian2
# Out:
# ...
#      |████████████████████████████████| 960 kB 71 kB/s
# ...
#      |████████████████████████████████| 6.2 MB 491 kB/s
# ...
#      |████████████████████████████████| 983 kB 1.1 MB/s
# ...
#      |████████████████████████████████| 532 kB 7.4 MB/s
# ...
# WARNING: You are using pip version 21.3.1; however, version 22.0.3 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.10/bin/python3.10 -m pip install --upgrade pip' command.

# %%
pip install --upgrade pip
# Out:
# ...
#      |████████████████████████████████| 2.1 MB 295 kB/s
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 21.3.1
#     Uninstalling pip-21.3.1:
#       Successfully uninstalled pip-21.3.1
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib pytest ipython notebook
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install brian2tools
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.9/87.9 KB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.9/67.9 KB 1.0 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.5/295.5 KB 1.1 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 2.0 MB/s eta 0:00:0000:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import brian2
brian2.test()
# Out:
# Running tests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brian2 for targets numpy, cython (excluding long tests)
# Running Brian version 2.5.0.3 from '/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/brian2'
# Testing codegen-independent code
# Resetting to default preferences
#
# Running doctests
# ..........................................                               [100%]
# 42 passed, 3 skipped in 13.91s
# Running tests that do not use code generation
# ........
# WARNING    Removing unsupported flag '-march=native' from compiler flags. [brian2.codegen.cpp_prefs]
# ................................................................ [ 19%]
# ............................................................
# ...
